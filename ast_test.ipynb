# %%
#https://greentreesnakes.readthedocs.io/en/latest/manipulating.html
import ast
class FuncLister(ast.NodeVisitor):
    lst = []
    def visit_FunctionDef(self, node):
        resp = ((node.__dict__['lineno'],node.__dict__['col_offset'],'def',node.name))
        self.lst.append(resp)
        #print(resp)
        self.generic_visit(node)
    def visit_Call(self, node):
        dct = node.__dict__['func'].__dict__
        if 'id' in dct.keys():
            resp = ((dct['lineno'],dct['col_offset'],'call',dct['id']))
            self.lst.append(resp)
        elif 'value' in dct.keys():
            dct_v1  = dct['value'].__dict__
            if 'id' in dct_v1.keys():
                resp = ((dct_v1['lineno'],dct_v1['col_offset'],'call',dct_v1['id']))
                self.lst.append(resp)
        self.generic_visit(node)
    
    def output_DataFrame(self):
        import pandas as pd 
        df = pd.DataFrame(self.lst)
        df.columns = ['line_no','col_offset','type','name']
        return df
    

f = open('/home/user/validate_inference_rules_sympy.py')
data  = f.read()
f.close()
tree = ast.parse(data)

X = FuncLister()
X.visit(tree)
df = X.output_DataFrame()
df.to_csv('sample.csv',index=False)

# %%
df.head(50)
# Out:
#     line_no  col_offset  type                                     name
# 0         9           9  call                                  logging
# 1        24           0   def                  split_expr_into_lhs_rhs
# 2        36           4  call                                   logger
# 3        38           4  call                                   logger
# 4        41          21  call                              parse_latex
# 5        43           8  call                                   logger
# 6        45           4  call                                   logger
# 7        47           4  call                                   logger
# 8        47          17  call                                      str
# 9        47          21  call                                    sympy
# 10       55           8  call                                   logger
# 11       56          63  call                                      str
# 12       58          14  call                                Exception
# 13       59          63  call                                      str
# 14       63           0   def                            validate_step
# 15       73           4  call                                   logger
# 16       75          10  call                                     clib
# 17       78           4  call                                   logger
# 18      106          23  call                  split_expr_into_lhs_rhs
# 19      115          39  call                                    sympy
# 20      117          12  call                                   logger
# 21      121          15  call                      add_X_to_both_sides
# 22      123          15  call               subtract_X_from_both_sides
# 23      125          15  call                   multiply_both_sides_by
# 24      127          15  call                     divide_both_sides_by
# 25      129          15  call                       substitute_X_for_Y
# 26      131          15  call                          add_zero_to_LHS
# 27      133          15  call                          add_zero_to_RHS
# 28      135          15  call                    multiply_LHS_by_unity
# 29      137          15  call                    multiply_RHS_by_unity
# 30      139          15  call                        swap_LHS_with_RHS
# 31      141          15  call                  take_curl_of_both_sides
# 32      143          15  call                         apply_divergence
# 33      145          15  call                 indefinite_integral_over
# 34      147          15  call                   indefinite_integration
# 35      149          15  call            indefinite_integrate_LHS_over
# 36      151          15  call            indefinite_integrate_RHS_over
# 37      153          15  call                   integrate_over_from_to
# 38      155          15  call  partially_differentiate_with_respect_to
# 39      157          15  call                    X_cross_both_sides_by
# 40      159          15  call                       both_sides_cross_X
# 41      161          15  call                         X_dot_both_sides
# 42      163          15  call                         both_sides_dot_X
# 43      165          15  call                          make_expr_power
# 44      167          15  call                        select_real_parts
# 45      169          15  call                        select_imag_parts
# 46      171          15  call                        sum_exponents_LHS
# 47      173          15  call                        sum_exponents_RHS
# 48      175          15  call                     add_expr_X_to_expr_Y
# 49      177          15  call            sub_RHS_of_expr_X_into_expr_Y
