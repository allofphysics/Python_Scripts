# %%
import pandas as pd
import numpy as np
from pandas import read_table
pd.set_option('display.max_rows',500)
pd.set_option('display.width',1000)

# %%
# !w3m  'http://www.sanfoundry.com/python-quiz-online/' >test2.txt

df=pd.read_table('test2.txt',names=['a'])
start=df.a[df.a.str.contains('1\.')].index.tolist()[0]
end=df.a[df.a.str.contains('Sanfoundry Global Education')].index.tolist()[0]
df=df[start:end]
df.replace('View Answer','',inplace=True)
questions_index_list=df[df.a.str.contains('^\d{1,}\..*\?')].index.tolist()
explanation_index=df[df.a.str.contains('Explanation')].index.tolist()
answer_index=df.a[df.a.str.contains('Answer')].index.tolist()

# %%
def prob_fun(start,stop):
    test=pd.Series(questions_index_list)
    problem=df.a.ix[test[start]:test[stop]-1]
    ans_index=(problem[problem.str.contains('Answer')].index.tolist())[0]
    for line in problem.ix[:ans_index-1]:
        print line
    test=raw_input()
    real_ans=df.ix[ans_index][0].split(':')[1].strip()
    if test==real_ans:
        print 'Correct'
    else:
        print "Not Correct"
        print '\n'
        for indx0 in problem.ix[ans_index:]:
            print indx0

# %%
for ix in  range(len(questions_index_list)-1):
    prob_fun(ix,ix+1)
# Out:
# 1. What is the output of the following?
# print("ab\tcd\tef".expandtabs())
# a) ab        cd        ef
# b) abcdef
# c) ab\tcd\tef
# d) ab    cd    ef
#
# a
# Correct
# 2. What is the output of the following?
# print("ab\tcd\tef".expandtabs(4))
# a) ab      cd      ef
# b) abcdef
# c) ab\tcd\tef
# d) ab    cd    ef
#
# d
# Correct
# 3. What is the output of the following?
# print("ab\tcd\tef".expandtabs('+'))
# a) ab+cd+ef
# b) ab++++++++cd++++++++ef
# c) ab        cd        ef
# d) none of the mentioned
#
# b
# Not Correct
#
#
# Answer: d
# Explanation: TypeError, an integer should be passed as an argument.
# 4. What is the output of the following?
# print("abcdef".find("cd") == "cd" in "abcdef")
# a) True
# b) False
# c) error
# d) none of the mentioned
#
# a
# Not Correct
#
#
# Answer: b
# Explanation: The function find() returns the position of the sunstring in the
# given string whereas the in keyword returns a value of Boolean type.
# advertisements
# 5. What is the output of the following?
# print("abcdef".find("cd"))
# a) True
# b) 2
# c) 3
# d) none of the mentioned
#
# b
# Correct
# 6. What is the output of the following?
# print("ccdcddcd".find("c"))
# a) 4
# b) 0
# c) error
# d) True
#
# b
# Correct
# 7. What is the output of the following?
# print("Hello {0} and {1}".format('foo', 'bin'))
# a) Hello foo and bin
# b) Hello {0} and {1} foo bin
# c) error
# d) Hello 0 and 1
#
# a
# Correct
# 8. What is the output of the following?
# advertisements
# 1151556193565aa6944adde_000007
# a) Hello foo and bin
# b) Hello bin and foo
# c) error
# d) none of the mentioned
#
# a
# Correct
# 9. What is the output of the following?
# print("Hello {} and {}".format('foo', 'bin'))
# a) Hello foo and bin
# b) Hello {} and {}
# c) error
# d) Hello and
#
# a
# Correct

# %%
match=df[(df.a.str.findall('\d\.\s').str.len()>0)].index.tolist()
#match2=df[(df.a.str.findall('\)').str.len()>0)].index.tolist()
#match3=df.a[(df.a.str.findall('^Answer').str.len()>0)].index.tolist()
strng=''

for indx,item in enumerate(match):
    if (indx < len(match)-1) and item+1==match[indx+1]:
            print (df.a.ix[item]).strip()
            
    else:
        for item in df.a.ix[item:item+6].tolist():
            if re.findall('^Answer',item):
                ans=raw_input()
                if ans==item.split(':')[1].strip():
                    print 'Correct'
                else:
                    print 'False'
                    print item.split(':')[1]
            else:
                print item.strip().replace('View Answer','')
        
        print '\n'
        
        #test=raw_input()

# %%
import re
import pandas as pd

# %%
df=df.ix[65:]
df
# Out:
#                                                      a
# 65   This section on Python aptitude questions and ...
# 66   1. Which of the following is the use of functi...
# 67        a) Functions are reusable pieces of programs
# 68   b) Functions don’t provide better modularity f...
# 69         c) you can’t also create your own functions
# 70                             d) All of the mentioned
# 71                                         View Answer
# 72                                           Answer: a
# 73   Explanation: Functions are reusable pieces of ...
# 74   a name to a block of statements, allowing you ...
# 75   specified name anywhere in your program and an...
# 76               2. Which keyword is use for function?
# 77                                              a) Fun
# 78                                           b) Define
# 79                                              c) Def
# 80                                         d) Function
# 81                                         View Answer
# 82                                           Answer: c
# 83                                  Explanation: None.
# 84         3. What is the output of the below program?
# 85                                  1. def sayHello():
# 86                        2.     print('Hello World!')
# 87                                       3. sayHello()
# 88                                       4. sayHello()
# 89                                     a) Hello World!
# 90                                        Hello World!
# 91                                   b) ‘Hello World!’
# 92                                      ‘Hello World!’
# 93                                            c) Hello
# 94                                               Hello
# ..                                                 ...
# 316                               Linux Device Drivers
# 317                                       Testimonials
# 318      It was a wonderful course, a thorough stud...
# 319      Storage Devices and the other advancements...
# 320      very informative for me. Well prepared sli...
# 321            interactive class. — Milind - Microsoft
# 322      The depth of C coverage, the common pitfal...
# 323      and his pace were all remarkable. Gave a c...
# 324         of C language design. — Shivanshu - Netapp
# 325      The course was well designed and coverage ...
# 326      linux programming assignments were designe...
# 327      issues and covered lot of areas of uncerta...
# 328      at the end of the course was invaluable. —...
# 329      Sanfoundry is No. 1 choice for Deep Hands-...
# 330      Kernel Programming. Our Founder has traine...
# 331      Companies in India such as VMware, Citrix,...
# 332      Aricent, HP, Intuit, Microsoft, Cisco, SAP...
# 333      Chelsio, Cavium, ST-Micro, Samsung, LG-Sof...
# 334      Accenture, HSBC, Mphasis, Tata-Elxsi, Tata...
# 335                                          Startups.
# 336                    • Terms of Use & Privacy Policy
# 337                                        • Copyright
# 338                                • Technology Groups
# 339                                          • Interns
# 340                                             • Jobs
# 341                                          • Sitemap
# 342       © 2011-2015 Sanfoundry. All Rights Reserved.
# 343                                               Show
# 344  Like Us to stay updated on 10000+ Free MCQs on...
# 345                                             daily!
#
# [281 rows x 1 columns]

# %%
df
# Out:
#                                                      a
# 0                                                 logo
# 1                                               • Home
# 2                                              • About
# 3                             • Courses | Fees | Dates
# 4                                   • College-Projects
# 5                                       • Testimonials
# 6                                         • Internship
# 7                                         • Developers
# 8                                               • Jobs
# 9                                            • Contact
# 10                                      advertisements
# 11                             1000 Python MCQs | Quiz
# 12                             Python - Core Datatypes
# 13                            Python - Basic Operators
# 14                             Python - Variable Names
# 15                        Python – Regular Expressions
# 16                              Python - Numeric Types
# 17                        Python - For-While Loops - 1
# 18                        Python - For-While Loops - 2
# 19                        Python - For-While Loops - 3
# 20                        Python - For-While Loops - 4
# 21                        Python - For-While Loops - 5
# 22                        Python - For-While Loops - 6
# 23                                Python - Strings - 1
# 24                                Python - Strings - 2
# 25                                Python - Strings - 3
# 26                                Python - Strings - 4
# 27                                Python - Strings - 5
# 28                                Python - Strings - 6
# 29                                Python - Strings - 7
# 30                                Python - Strings - 8
# 31                                Python - Strings - 9
# 32                               Python - Strings - 10
# 33                               Python - Strings - 11
# 34                               Python - Strings - 12
# 35                               Python - Strings - 13
# 36                                  Python - Lists - 1
# 37                                  Python - Lists - 2
# 38                                  Python - Lists - 3
# 39                                  Python - Lists - 4
# 40                                  Python - Lists - 5
# 41                                 Python - Dictionary
# 42                                     Python - Tuples
# 43                                  Python - Files - 1
# 44                                  Python - Files - 2
# 45                                  Python - Files - 3
# 46                                  Python - Files - 4
# 47                                  Python - Files - 5
# 48                               Python - Function - 1
# 49                               Python - Function - 2
# 50                               Python - Function - 3
# 51                         Python - Exception Handling
# 52                         Python - Argument Passing 1
# 53                         Python - Argument Passing 2
# 54                         Python - List Comprehension
# 55                      Python - Mapping Functions - 1
# 56                      Python - Mapping Functions - 2
# 57                      Python - Mapping Functions - 3
# 58                       Python - Operator Overloading
# 59                              Python - Random Module
# 60                                   Python - Math - 1
# 61                                   Python - Math - 2
# 62                                   Python - Math - 3
# 63                           Python - Operating System
# 64         Python Questions and Answers – Function – 1
# 65   This section on Python aptitude questions and ...
# 66   1. Which of the following is the use of functi...
# 67        a) Functions are reusable pieces of programs
# 68   b) Functions don’t provide better modularity f...
# 69         c) you can’t also create your own functions
# 70                             d) All of the mentioned
# 71                                         View Answer
# 72                                           Answer: a
# 73   Explanation: Functions are reusable pieces of ...
# 74   a name to a block of statements, allowing you ...
# 75   specified name anywhere in your program and an...
# 76               2. Which keyword is use for function?
# 77                                              a) Fun
# 78                                           b) Define
# 79                                              c) Def
# 80                                         d) Function
# 81                                         View Answer
# 82                                           Answer: c
# 83                                  Explanation: None.
# 84         3. What is the output of the below program?
# 85                                  1. def sayHello():
# 86                        2.     print('Hello World!')
# 87                                       3. sayHello()
# 88                                       4. sayHello()
# 89                                     a) Hello World!
# 90                                        Hello World!
# 91                                   b) ‘Hello World!’
# 92                                      ‘Hello World!’
# 93                                            c) Hello
# 94                                               Hello
# 95                            d) None of the mentioned
# 96                                         View Answer
# 97                                           Answer: a
# 98   Explanation: Functions are defined using the d...
# 99   comes an identifier name for the function, fol...
# 100  which may enclose some names of variables, and...
# 101  line. Next follows the block of statements tha...
# 102                                 1. def sayHello():
# 103   2.     print('Hello World!') # block belongin...
# 104                             3. # End of function #
# 105                                               4.
# 106                  5. sayHello() # call the function
# 107            6. sayHello() # call the function again
# 108        4. What is the output of the below program?
# 109                             1. def printMax(a, b):
# 110                                   2.     if a > b:
# 111                  3.         print(a, 'is maximum')
# 112                              4.     elseif a == b:
# 113              5.         print(a, 'is equal to', b)
# 114                                       6.     else:
# 115                  7.         print(b, 'is maximum')
# 116                                  8. printMax(3, 4)
# 117                                               a) 3
# 118                                               b) 4
# 119                                    c) 4 is maximum
# 120                           d) None of the mentioned
# 121                                        View Answer
# 122                                          Answer: c
# 123  Explanation: Here, we define a function called...
# 124  parameters called a and b. We find out the gre...
# 125  if..else statement and then print the bigger n...
# 126       5. What is the output of the below program ?
# 127                                     advertisements
# 128                     1669657150564fe2bd91127_000003
# 129                                   a) x is still 50
# 130                                    b) x is still 2
# 131                                  c) x is still 100
# 132                           d) None of the mentioned
# 133                                        View Answer
# 134                                          Answer: a
# 135  Explanation: The first time that we print the ...
# 136  first line in the function’s body, Python uses...
# 137  declared in the main block, above the function...
# 138  Next, we assign the value 2 to x. The name x i...
# 139  we change the value of x in the function, the ...
# 140                                remains unaffected.
# 141  With the last print function call, we display ...
# 142  main block, thereby confirming that it is actu...
# 143  assignment within the previously called function.
# 144        6. What is the output of the below program?
# 145                                          1. x = 50
# 146                                               2.
# 147                                     3. def func():
# 148                                    4.     global x
# 149                                               5.
# 150                            6.     print('x is', x)
# 151                                       7.     x = 2
# 152             8.     print('Changed global x to', x)
# 153                                          9. func()
# 154                      10. print('Value of x is', x)
# 155                                         a) x is 50
# 156                              Changed global x to 2
# 157                                   Value of x is 50
# 158                                         b) x is 50
# 159                              Changed global x to 2
# 160                                    Value of x is 2
# 161                                         c) x is 50
# 162                             Changed global x to 50
# 163                                   Value of x is 50
# 164                           d) None of the mentioned
# 165                                        View Answer
# 166                                          Answer: b
# 167  Explanation: The global statement is used to d...
# 168  variable – hence, when we assign a value to x ...
# 169  is reflected when we use the value of x in the...
# 170            7. What is the output of below program?
# 171                    1. def say(message, times = 1):
# 172                      2.     print(message * times)
# 173                                               3.
# 174                                    4. say('Hello')
# 175                                 5. say('World', 5)
# 176                                           a) Hello
# 177                          WorldWorldWorldWorldWorld
# 178                                           b) Hello
# 179                                            World 5
# 180                                           c) Hello
# 181                      World,World,World,World,World
# 182                                           d) Hello
# 183                                                  d
# 184                                        View Answer
# 185                                          Answer: a
# 186  Explanation: For some functions, you may want ...
# 187  and use default values in case the user does n...
# 188  them. This is done with the help of default ar...
# 189  default argument values for parameters by appe...
# 190  the function definition the assignment operato...
# 191                                             value.
# 192  The function named say is used to print a stri...
# 193  we don’t supply a value, then by default, the ...
# 194  achieve this by specifying a default argument ...
# 195                                             times.
# 196  In the first usage of say, we supply only the ...
# 197  once. In the second usage of say, we supply bo...
# 198  stating that we want to say the string message...
# 199        8. What is the output of the below program?
# 200                         1. def func(a, b=5, c=10):
# 201   2.     print('a is', a, 'and b is', b, 'and c...
# 202                                               3.
# 203                                      4. func(3, 7)
# 204                                5. func(25, c = 24)
# 205                           6. func(c = 50, a = 100)
# 206                   a) a is 7 and b is 3 and c is 10
# 207                     a is 25 and b is 5 and c is 24
# 208                    a is 5 and b is 100 and c is 50
# 209                   b) a is 3 and b is 7 and c is 10
# 210                     a is 5 and b is 25 and c is 24
# 211                    a is 50 and b is 100 and c is 5
# 212                   c) a is 3 and b is 7 and c is 10
# 213                     a is 25 and b is 5 and c is 24
# 214                    a is 100 and b is 5 and c is 50
# 215                           d) None of the mentioned
# 216                                        View Answer
# 217                                          Answer: c
# 218  Explanation: If you have some functions with m...
# 219  specify only some of them, then you can give v...
# 220  naming them – this is called keyword arguments...
# 221  instead of the position (which we have been us...
# 222                         arguments to the function.
# 223  The function named func has one parameter with...
# 224  followed by two parameters with default argume...
# 225                                     advertisements
# 226  In the first usage, func(3, 7), the parameter ...
# 227  b gets the value 7 and c gets the default valu...
# 228  In the second usage func(25, c=24), the variab...
# 229  the position of the argument. Then, the parame...
# 230  naming i.e. keyword arguments. The variable b ...
# 231  In the third usage func(c=50, a=100), we use k...
# 232  specified values. Notice that we are specifyin...
# 233  before that for a even though a is defined bef...
# 234            9. What is the output of below program?
# 235                              1. def maximum(x, y):
# 236                                   2.     if x > y:
# 237                                3.         return x
# 238                                4.     elif x == y:
# 239          5.         return 'The numbers are equal'
# 240                                       6.     else:
# 241                                7.         return y
# 242                                               8.
# 243                            9. print(maximum(2, 3))
# 244                                               a) 2
# 245                                               b) 3
# 246                           c) The numbers are equal
# 247                           d) None of the mentioned
# 248                                        View Answer
# 249                                          Answer: b
# 250  Explanation: The maximum function returns the ...
# 251  this case the numbers supplied to the function...
# 252  statement to find the greater value and then r...
# 253  10. Which of the following is a features of Do...
# 254  a) Provide a convenient way of associating doc...
# 255                    functions, classes, and methods
# 256           b) All functions should have a docstring
# 257  c) Docstrings can be accessed by the __doc__ a...
# 258                            d) All of the mentioned
# 259                                        View Answer
# 260                                          Answer: d
# 261  Explanation: Python has a nifty feature called...
# 262  referred to by its shorter name docstrings. Do...
# 263  that you should make use of since it helps to ...
# 264                     makes it easier to understand.
# 265  Sanfoundry Global Education & Learning Series ...
# 266  Here’s the list of Best Reference Books in Pyt...
# 267  To practice all features of Python programming...
# 268  set of 1000+ Multiple Choice Questions and Ans...
# 269  « Discrete Mathematics Questions and Answers –...
# 270                                      Well-Ordering
# 271      Python Questions and Answers – Function – 2 »
# 272                                     advertisements
# 273                            Deep Dive @ Sanfoundry:
# 274                          1. C Programming Examples
# 275     2. C++ Templates Training and Meta Programming
# 276   3. Linux Device Drivers Training – II – Block...
# 277                               4. Simple C Programs
# 278           5. FTP – File Transfer Protocol Training
# 279            6. C# Programming Examples on Functions
# 280                    7. Python Questions and Answers
# 281                                 8. Python Training
# 282  Manish Bhojasia, a technology veteran with 19+...
# 283  Founder and CTO at Sanfoundry. He is Linux Ker...
# 284  and is passionate about competency development...
# 285  Bangalore and delivers focused training sessio...
# 286  Kernel, Linux Debugging, Linux Device Drivers,...
# 287  & Cluster Administration, Advanced C Programmi...
# 288  SCSI Internals and Storage Protocols such as i...
# 289                           connected with us below:
# 290            Google+ | Facebook | Twitter | LinkedIn
# 291                     Subscribe Sanfoundry Newsle...
# 292                      Name * [                    ]
# 293             Email Address * [                    ]
# 294                                        [Subscribe]
# 295                                       Best Careers
# 296                                   Developer Tracks
# 297                                      SAN Developer
# 298                             Linux Kernel Developer
# 299                             Linux Driver Developer
# 300                            Linux Network Developer
# 301                               Live Training Photos
# 302                                          Mentoring
# 303                              Software Productivity
# 304                                     GDB Assignment
# 305                                      Best Training
# 306                                 SAN I - Technology
# 307                                     SAN II - Admin
# 308                                 Linux Fundamentals
# 309                                Advanced C Training
# 310                                  Linux-C Debugging
# 311                                 System Programming
# 312                                Network Programming
# 313                                      Linux Threads
# 314                                 Kernel Programming
# 315                                   Kernel Debugging
# 316                               Linux Device Drivers
# 317                                       Testimonials
# 318      It was a wonderful course, a thorough stud...
# 319      Storage Devices and the other advancements...
# 320      very informative for me. Well prepared sli...
# 321            interactive class. — Milind - Microsoft
# 322      The depth of C coverage, the common pitfal...
# 323      and his pace were all remarkable. Gave a c...
# 324         of C language design. — Shivanshu - Netapp
# 325      The course was well designed and coverage ...
# 326      linux programming assignments were designe...
# 327      issues and covered lot of areas of uncerta...
# 328      at the end of the course was invaluable. —...
# 329      Sanfoundry is No. 1 choice for Deep Hands-...
# 330      Kernel Programming. Our Founder has traine...
# 331      Companies in India such as VMware, Citrix,...
# 332      Aricent, HP, Intuit, Microsoft, Cisco, SAP...
# 333      Chelsio, Cavium, ST-Micro, Samsung, LG-Sof...
# 334      Accenture, HSBC, Mphasis, Tata-Elxsi, Tata...
# 335                                          Startups.
# 336                    • Terms of Use & Privacy Policy
# 337                                        • Copyright
# 338                                • Technology Groups
# 339                                          • Interns
# 340                                             • Jobs
# 341                                          • Sitemap
# 342       © 2011-2015 Sanfoundry. All Rights Reserved.
# 343                                               Show
# 344  Like Us to stay updated on 10000+ Free MCQs on...
# 345                                             daily!
